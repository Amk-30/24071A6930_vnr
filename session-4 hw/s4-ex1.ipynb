# %%
import numpy as np
import seaborn as sns
import pandas as pd
df=pd.read_csv('iris.csv')
sns.scatterplot(data =df,x= 'sepal_width',y='sepal_length')
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %%
import numpy as np
import seaborn as sns
import pandas as pd
df=pd.read_csv('iris.csv')
sns.scatterplot(data =df,x= 'sepal_width',y='petal_length')
# Out:
# <Axes: xlabel='sepal_width', ylabel='petal_length'>

# %%
import numpy as np
import seaborn as sns
import pandas as pd
df=pd.read_csv('iris.csv')
sns.scatterplot(data =df,x= 'petal_width',y='sepal_length')
# Out:
# <Axes: xlabel='petal_width', ylabel='sepal_length'>

# %%
import numpy as np
import seaborn as sns
import pandas as pd
df=pd.read_csv('iris.csv')
sns.scatterplot(data =df,x= 'petal_width',y='petal_length')
# Out:
# <Axes: xlabel='petal_width', ylabel='petal_length'>
